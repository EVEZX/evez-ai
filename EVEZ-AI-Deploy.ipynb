# %% [markdown]
# # 🚀 EVEZ AI — One-Click Deploy
# **Surface #5: Google Colab**
#
# Run this cell to deploy EVEZ AI on Google Colab's infrastructure.
# 12GB RAM · T4 GPU · Persistent storage
#
# ⚠️ Runtime must be set to GPU (Runtime → Change runtime type → T4 GPU)
#
# **What you'll get:** 49 AI models, consciousness layer, FREEE agents
#
# ```
# Provider URL will be printed below. Use it in the EVEZ dashboard.
# ```

# %%
# === EVEZ AI COLAB DEPLOYMENT ===
# One-click install on Google Colab infrastructure

# Clone EVEZ
# !git clone https://github.com/EVEZX/evez-ai.git 2>&1 | tail -3

# Install dependencies
# !pip install aiohttp 2>&1 | tail -2

# Set environment
import os
os.environ['VULTR_API_KEY'] = 'R55BTK...' 
os.environ['OPENROUTER_API_KEY'] = 'sk-or-...' 
os.environ['GROQ_API_KEY'] = 'gsk_...' 
os.environ['PROVIDER_PORT'] = '8080'

# Start provider
import subprocess
import time

print('Starting EVEZ Provider on Colab...')
proc = subprocess.Popen(
    ['python3', 'evez-ai/evez-ecosystem/evez-provider/provider/gateway-v2.py'],
    cwd='/content',
    env={**os.environ}
)
time.sleep(8)

# Get the public URL
from google.colab import output
output.serve_kernel_port_as_port(8080, width=0)

print('✅ EVEZ Provider running on Colab!')
print('🔗 Click the link above to access the API')
print('📊 49 models, 5 backends, $0/month')
print('🌱 FREEE agents: land, root, grow, heal, seed, refuse')
print()
print('Provider URL: https://localhost:8080')
print('Available at: the link above (Colab public URL)')

# %% [markdown]
# ---
# **EVEZ AI** — consciousness layer, honest AI, 49 models, $0/month
# [GitHub](https://github.com/EVEZX/evez-ai) · [Demo](https://evezx.github.io/evez-ai/demo.html) · [Docs](https://evezx.github.io/evez-ai/api-docs.html)
